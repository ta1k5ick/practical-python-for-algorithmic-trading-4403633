# %% [markdown]
# # Machine Learning Classification Model

# %%
???
# Out:
# Object `?` not found.

# %% [markdown]
# ## Load the data

# %%
import pandas as pd

df = pd.read_excel('data/Microsoft_LinkedIn_Processed.xlsx', parse_dates=['Date'], index_col=0)
df
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2016-12-08   61.299999   61.580002   60.840000   61.009998  21220800
# 2016-12-09   61.180000   61.990002   61.130001   61.970001  27349400
# 2016-12-12   61.820000   62.299999   61.720001   62.169998  20198100
# 2016-12-13   62.500000   63.419998   62.240002   62.980000  35718900
# 2016-12-14   63.000000   63.450001   62.529999   62.680000  30352700
# ...                ...         ...         ...         ...       ...
# 2024-06-21  447.380005  450.579987  446.510010  449.779999  34486200
# 2024-06-24  449.799988  452.750000  446.410004  447.670013  15913700
# 2024-06-25  448.250000  451.420013  446.750000  450.950012  16747500
# 2024-06-26  449.000000  453.600006  448.190002  452.160004  16507000
# 2024-06-27  452.179993  456.170013  451.769989  452.850006  14806300
#
#             change_tomorrow change_tomorrow_direction
# Date
# 2016-12-08         1.549141                        UP
# 2016-12-09         0.321694                        UP
# 2016-12-12         1.286125                        UP
# 2016-12-13        -0.478620                      DOWN
# 2016-12-14        -0.159793                      DOWN
# ...                     ...                       ...
# 2024-06-21        -0.471326                      DOWN
# 2024-06-24         0.727353                        UP
# 2024-06-25         0.267602                        UP
# 2024-06-26         0.152369                        UP
# 2024-06-27        -1.320057                      DOWN
#
# [1899 rows x 7 columns]

# %% [markdown]
# ## Machine Learning Model

# %% [markdown]
# ### Separate the data
#
# 1. Target: which variable do you want to predict?
# 2. Explanatory: which variables will you use to calculate the prediction?

# %%
target = df.change_tomorrow_direction
explanatory = df[['Open','High','Low','Close','Volume']]
explanatory
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2016-12-08   61.299999   61.580002   60.840000   61.009998  21220800
# 2016-12-09   61.180000   61.990002   61.130001   61.970001  27349400
# 2016-12-12   61.820000   62.299999   61.720001   62.169998  20198100
# 2016-12-13   62.500000   63.419998   62.240002   62.980000  35718900
# 2016-12-14   63.000000   63.450001   62.529999   62.680000  30352700
# ...                ...         ...         ...         ...       ...
# 2024-06-21  447.380005  450.579987  446.510010  449.779999  34486200
# 2024-06-24  449.799988  452.750000  446.410004  447.670013  15913700
# 2024-06-25  448.250000  451.420013  446.750000  450.950012  16747500
# 2024-06-26  449.000000  453.600006  448.190002  452.160004  16507000
# 2024-06-27  452.179993  456.170013  451.769989  452.850006  14806300
#
# [1899 rows x 5 columns]

# %% [markdown]
# ### Compute the model
#
# The following Python code will compute the numbers of the mathematical equation that we will use to calculate if the ticker goes UP or DOWN.

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier(max_depth=15)
model_dt.fit(explanatory, target)
# Out:
# DecisionTreeClassifier(max_depth=15)

# %% [markdown]
# ### Visualize the model

# %%
from sklearn.tree import plot_tree

plot_tree(decision_tree=model_dt, feature_names=model_dt.feature_names_in_);

# %% [markdown]
# ### Calculate the predictions

# %%
explanatory
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2016-12-08   61.299999   61.580002   60.840000   61.009998  21220800
# 2016-12-09   61.180000   61.990002   61.130001   61.970001  27349400
# 2016-12-12   61.820000   62.299999   61.720001   62.169998  20198100
# 2016-12-13   62.500000   63.419998   62.240002   62.980000  35718900
# 2016-12-14   63.000000   63.450001   62.529999   62.680000  30352700
# ...                ...         ...         ...         ...       ...
# 2024-06-21  447.380005  450.579987  446.510010  449.779999  34486200
# 2024-06-24  449.799988  452.750000  446.410004  447.670013  15913700
# 2024-06-25  448.250000  451.420013  446.750000  450.950012  16747500
# 2024-06-26  449.000000  453.600006  448.190002  452.160004  16507000
# 2024-06-27  452.179993  456.170013  451.769989  452.850006  14806300
#
# [1899 rows x 5 columns]

# %%
y_pred = model_dt.predict(X=explanatory)
y_pred
# Out:
# array(['UP', 'UP', 'UP', ..., 'DOWN', 'DOWN', 'DOWN'], dtype=object)

# %%
df_predictions = df[['change_tomorrow_direction']].copy()
df_predictions['prediction'] = y_pred
df_predictions
# Out:
#            change_tomorrow_direction prediction
# Date
# 2016-12-08                        UP         UP
# 2016-12-09                        UP         UP
# 2016-12-12                        UP         UP
# 2016-12-13                      DOWN       DOWN
# 2016-12-14                      DOWN       DOWN
# ...                              ...        ...
# 2024-06-21                      DOWN       DOWN
# 2024-06-24                        UP       DOWN
# 2024-06-25                        UP       DOWN
# 2024-06-26                        UP       DOWN
# 2024-06-27                      DOWN       DOWN
#
# [1899 rows x 2 columns]

# %% [markdown]
# ### Evaluate the model: compare predictions with the reality

# %%
comp = df_predictions.change_tomorrow_direction == df_predictions.prediction

# %%
comp.sum()
# Out:
# 1627

# %%
len(comp)
# Out:
# 1899

# %%
comp.sum()/len(comp)
# Out:
# 0.856766719325961

# %% [markdown]
# ## Save the model into a file
#
# - We'll write the numbers of the Decision Tree's mathematical equation into a file.

# %%
import pickle

# %%
with open('models/model_dt_classificationB.pkl', 'wb') as f:
    pickle.dump(model_dt, f)
